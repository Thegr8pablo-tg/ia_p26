# %% [markdown]
# # 03 Segmentacion de arquetipos
#
# Notebook de apoyo para revisar los arquetipos finales.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..') if Path.cwd().name == 'notebooks' else Path('.')
scoreados = pd.read_csv(ROOT / 'data/processed/clientes_personales_scoreados.csv')
resumen = pd.read_csv(ROOT / 'data/processed/resumen_arquetipos.csv')
resumen

# %%
scoreados[scoreados['seleccionado']].groupby('arquetipo')['score_empresarial'].agg(['count', 'mean', 'min', 'max']).round(4)
