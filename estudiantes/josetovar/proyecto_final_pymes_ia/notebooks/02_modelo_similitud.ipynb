# %% [markdown]
# # 02 Modelo de similitud
#
# Notebook de apoyo para inspeccionar scores e importancia de variables.

# %%
from pathlib import Path
import pandas as pd

ROOT = Path('..') if Path.cwd().name == 'notebooks' else Path('.')
scoreados = pd.read_csv(ROOT / 'data/processed/clientes_personales_scoreados.csv')
importancias = pd.read_csv(ROOT / 'data/processed/importancia_variables.csv')
scoreados[['cliente_id', 'score_empresarial', 'seleccionado']].head()

# %%
scoreados['score_empresarial'].describe(), importancias.head(10)
